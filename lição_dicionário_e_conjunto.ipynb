# %% [markdown]
# <a href="https://colab.research.google.com/github/GuiNunes477/Etec2026/blob/main/li%C3%A7%C3%A3o_dicion%C3%A1rio_e_conjunto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Dicionarios 1.
aluno = {
    "Nome" : "Guilherme",
    "Idade" : 15,
    "Curso" : "T.I"
}
print(aluno)
# Out:
# {'Nome': 'Guilherme', 'Idade': 15, 'Curso': 'T.I'}

# %%
# 2.
aluno = {
    "Nome" : "Guilherme",
    "Idade" : 15,
    "Curso" : "T.I"
}
print(aluno["Nome"])
print(aluno["Idade"])
print(aluno["Curso"])
# Out:
# Guilherme
# 15
# T.I

# %%
# 3.
produto = {
  "Nome" : "Coca-Cola",
  "Preço" : 10.00,
  "Estoque" : 100
}
print(produto)
produto.update({"Preço" : 12.00})
print(produto)
# Out:
# {'Nome': 'Coca-Cola', 'Preço': 10.0, 'Estoque': 100}
# {'Nome': 'Coca-Cola', 'Preço': 12.0, 'Estoque': 100}

# %%
# 4.
aluno = {
    "Nome" : "Guilherme",
    "Idade" : 15,
}
print(aluno)
aluno["Curso"] = "T.I"
print(aluno)
# Out:
# {'Nome': 'Guilherme', 'Idade': 15}
# {'Nome': 'Guilherme', 'Idade': 15, 'Curso': 'T.I'}

# %%
# 5.
filme = {
"Titulo" : "Efeito Borboleta",
"Ano" : 2004,
"Gênero" : "ficção científica",
"Nota" : 7.6
}
print(filme["Titulo"])
print(filme["Ano"])
print(filme["Gênero"])
print(filme["Nota"])
# Out:
# Efeito Borboleta
# 2004
# ficção científica
# 7.6

# %%
# Conjuntos 1.
numeros = {1,2,3,4,5}
print(numeros)
# Out:
# {1, 2, 3, 4, 5}

# %%
# 2.
numeros = {1,2,2,3,3,3,4,5}
print("numeros")
# As repetições somem

# %%
# 3.
frutas = {"maçã", "Banana", "Laranja",}
print(frutas)
frutas.add("morango")
print(frutas)
# Out:
# {'Laranja', 'maçã', 'Banana'}
# {'morango', 'Laranja', 'maçã', 'Banana'}

# %%
# 4.
cores = {"vermelho", "azul", "verde", "Amarelo"}
print(cores)
cores.remove("verde")
print(cores)
# Out:
# {'vermelho', 'verde', 'Amarelo', 'azul'}
# {'vermelho', 'Amarelo', 'azul'}

# %%
# 5.
nomes = ["Yris", "Luna", "Luna", "Maitê", "Yris", "Ravi", "Gael", "Theo", "Theo"]
nomes = {"Yris", "Luna", "Luna", "Maitê", "Yris", "Ravi", "Gael", "Theo", "Theo"}
print(nomes)
# Out:
# {'Ravi', 'Luna', 'Gael', 'Theo', 'Maitê', 'Yris'}
